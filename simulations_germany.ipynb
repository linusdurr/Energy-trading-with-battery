# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.battery import Battery
from src.optimize import run_simulation
from src.load_data import load_data
from src.plot import display_schedule, display_profit, get_stats

import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Battery specs :

# %% [markdown]
# - SOC: practical state of charge in [0,1]
# - NEC: practical nominal energy capacity (Wh)
# - CR: Charging rate (W/Wh)
# - DR: Discharging rate (W/Wh)

# %%
SOC = np.array([0, 0.01, 0.85, 1.0])

# Charging curve
CR = np.array([0.25, 0.5, 0.5, 0.1])

SOC_to_CR_function = interp1d(SOC, CR)

# Discharging curve
SOC = np.array([0.0, 0.15, 0.99, 1.0])
DR = np.array([0.1, 0.5, 0.5, 0.25])

SOC_to_DR_function = interp1d(SOC, DR)

bat = Battery(SOC_to_CR_function, SOC_to_DR_function)

# %%
plt.figure(figsize=(10, 3))
plt.plot(
    np.linspace(0, 1, 100),
    SOC_to_CR_function(np.linspace(0, 1, 100)),
    label="Charging curve $f_c$",
)
plt.plot(
    np.linspace(0, 1, 100),
    -SOC_to_DR_function(np.linspace(0, 1, 100)),
    label="Discharging curve $f_d$",
)
plt.grid(True)
plt.xlabel("$SOC$", fontdict=dict(size=15))
plt.ylabel("Rate $r$ (W/Wh)", fontdict=dict(size=15))
plt.legend(loc="upper center", fontsize=15)
plt.tight_layout()
plt.savefig("out/charging_curve.pdf")
plt.show()

# %% [markdown]
# # Compute max SOC change in one hour of charge/ discharge

# %%
Nint = 5
G_c, G_d = bat.get_max_SOC_change(Nint)


Nint2 = 100
G_c2, G_d2 = bat.get_max_SOC_change(Nint2)

# %%
import matplotlib.pyplot as plt

plt.rc("text", usetex=False)

plt.figure(figsize=(10, 3))
plt.grid(True)
plt.plot(np.linspace(0, 1, Nint + 1), G_c)
plt.plot(
    np.linspace(0, 1, Nint2 + 1),
    G_c2,
    label="interpolation with {} intervals".format(Nint),
)
plt.ylabel(r"Max SOC change $\overline{\Delta}$")
plt.xlabel("$SOC$")
plt.title("Max energy change after one hour of charge")
plt.legend()
plt.tight_layout()
plt.savefig("out/max_energy_change.pdf")
plt.show()


plt.figure(figsize=(10, 3))
plt.grid(True)
plt.plot(np.linspace(0, 1, Nint + 1), G_d)
plt.plot(
    np.linspace(0, 1, Nint2 + 1),
    G_d2,
    label="interpolation with {} intervals".format(Nint),
)
plt.ylabel(r"Min SOC change   $\underbar \!\!\! \Delta $")
plt.xlabel("$SOC$")
plt.title("Max energy change after one hour of discharge")
plt.legend()
plt.tight_layout()
plt.savefig("out/min_energy_change.pdf")
plt.show()

# %% [markdown]
# # Dataset :

# %%
country = "Germany"

# %%
df = load_data(country=country, start="2021-01-01 00:00:00")
df
# Out:
#         Country ISO3 Code           timestamp     Datetime (Local)  \
# 387912  Germany       DEU 2021-01-01 00:00:00  2021-01-01 01:00:00
# 387913  Germany       DEU 2021-01-01 01:00:00  2021-01-01 02:00:00
# 387914  Germany       DEU 2021-01-01 02:00:00  2021-01-01 03:00:00
# 387915  Germany       DEU 2021-01-01 03:00:00  2021-01-01 04:00:00
# 387916  Germany       DEU 2021-01-01 04:00:00  2021-01-01 05:00:00
# ...         ...       ...                 ...                  ...
# 405427  Germany       DEU 2022-12-31 19:00:00  2022-12-31 20:00:00
# 405428  Germany       DEU 2022-12-31 20:00:00  2022-12-31 21:00:00
# 405429  Germany       DEU 2022-12-31 21:00:00  2022-12-31 22:00:00
# 405430  Germany       DEU 2022-12-31 22:00:00  2022-12-31 23:00:00
# 405431  Germany       DEU 2022-12-31 23:00:00  2023-01-01 00:00:00
#
#         price_euros_wh       vgc  fgc
# 387912        0.000048  0.000005    0
# 387913        0.000045  0.000005    0
# 387914        0.000043  0.000005    0
# 387915        0.000040  0.000005    0
# 387916        0.000040  0.000005    0
# ...                ...       ...  ...
# 405427        0.000023  0.000005    0
# 405428       -0.000001  0.000005    0
# 405429       -0.000001  0.000005    0
# 405430        0.000025  0.000005    0
# 405431       -0.000005  0.000005    0
#
# [17520 rows x 7 columns]

# %% [markdown]
# # true prices :

# %%
frame_size_forecast = 28
update_period = 1

df_optim = run_simulation(
    bat,
    start="2022-01-01 00:00:00",
    end="2023-01-01 00:00:00",
    df=df,
    forecasted=False,
    frame_size=frame_size_forecast,
    update_period=update_period,
)


display_schedule(df_optim, name=country + "_optim_" + str(frame_size_forecast))
display_profit(df_optim, name=country + "_optim_" + str(frame_size_forecast))
# Out:
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 97.59291234
# 160 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 44.01021739
# 418 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 154.5624587
# 214 simplex iterations
# 1 branching nodes
# absmipgap=1.08899e-07, relmipgap=7.0456e-10
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 79.69728902
# 234 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 72.58543329
# 251 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 160.4771932
# 232 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 133.7426134
# 163 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 70.23092447
# 191 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 178.0021052
# 154 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 120.7712608
# 230 simplex iterations
# 1 branching nodes
# absmipgap=0.00998321, relmipgap=8.26621e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 142.9430216
# 169 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 139.861223
# 221 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 122.8758843
# 194 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 182.7801494
# 226 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 77.61643429
# 217 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 5.726050627
# 196 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 233.6228574
# 200 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 112.4163185
# 227 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 85.89107135
# 205 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 133.819797
# 226 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 97.77226911
# 191 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.6690113
# 217 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 56.14417501
# 238 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 177.6778001
# 191 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 246.015733
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 100.9022362
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 26.60304323
# 235 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 161.9194669
# 169 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 90.09227855
# 261 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 150.4143133
# 227 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 175.5715508
# 176 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 71.36942539
# 159 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.1764929300230472e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 242.1767275
# 202 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 78.05692963
# 241 simplex iterations
# 1 branching nodes
# absmipgap=0.00524743, relmipgap=6.72257e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 76.99624108
# 234 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 121.2710159
# 202 simplex iterations
# 1 branching nodes
# absmipgap=4.26326e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 119.3930308
# 263 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 228.7351627
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 94.54693093
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 169.119688
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 95.93775186
# 236 simplex iterations
# 1 branching nodes
# absmipgap=8.52651e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 137.2989268
# 275 simplex iterations
# 1 branching nodes
# absmipgap=1.82679e-07, relmipgap=1.33052e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 88.21526882
# 151 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 67.64874314
# 159 simplex iterations
# 1 branching nodes
# absmipgap=1.78993e-07, relmipgap=2.64591e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 172.2196969
# 214 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.5386954
# 184 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 86.16760707
# 178 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.1781003348491523e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 145.0764858
# 398 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 127.3740973
# 218 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.1783324053727134e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 105.1100376
# 171 simplex iterations
# 1 branching nodes
# absmipgap=0.00356224, relmipgap=3.38906e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 44.96631602
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 135.9529569
# 208 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 130.572428
# 208 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 182.1435837
# 231 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 84.92998831
# 201 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 106.0162565
# 240 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 196.415863
# 170 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 147.1386816
# 205 simplex iterations
# 1 branching nodes
# absmipgap=0.000694331, relmipgap=4.71889e-06
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 265.3637257
# 227 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 262.2474777
# 220 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 222.2210106
# 226 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 199.1136076
# 205 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 172.5346098
# 214 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 152.460189
# 221 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 204.4576103
# 239 simplex iterations
# 1 branching nodes
# absmipgap=0.0145144, relmipgap=7.09898e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 319.5725624
# 243 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 569.8768017
# 219 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 381.078638
# 219 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 313.5597278
# 264 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 213.9871556
# 227 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 220.5497949
# 235 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 220.8339905
# 215 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 282.5702722
# 204 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 173.8838788
# 182 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 153.4851267
# 231 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 228.2334019
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 130.8525101
# 204 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 158.5359091
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 137.9934569
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 292.4366016
# 229 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 185.5486269
# 195 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 217.4961506
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 208.0077766
# 185 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 212.4041564
# 231 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 189.8384761
# 180 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 172.7745333
# 146 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 229.233531
# 194 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 143.202717
# 202 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 114.0683885
# 220 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 125.4480666
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 137.8783088
# 184 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 152.1847804
# 226 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 90.66032245
# 141 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 62.44956006
# 238 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 243.1350137
# 243 simplex iterations
# 1 branching nodes
# absmipgap=0.0225556, relmipgap=9.27699e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 127.5454924
# 226 simplex iterations
# 1 branching nodes
# absmipgap=0.000602646, relmipgap=4.72495e-06
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 30.56533573
# 211 simplex iterations
# 1 branching nodes
# absmipgap=3.55271e-15, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 290.0205011
# 224 simplex iterations
# 1 branching nodes
# absmipgap=0.0260657, relmipgap=8.98754e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 89.11353053
# 312 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 235.4265129
# 182 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 184.2853869
# 209 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 179.3975132
# 213 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 178.0606614
# 183 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 123.0449003
# 190 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 71.16206244
# 251 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 149.6882255
# 194 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 182.3537606
# 242 simplex iterations
# 1 branching nodes
# absmipgap=0.00743727, relmipgap=4.07848e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 186.1229182
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 133.4614512
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 118.0238265
# 177 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 99.03929098
# 206 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 152.3829852
# 223 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 166.4894743
# 264 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 169.015422
# 176 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 130.0723196
# 242 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 123.9088276
# 214 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 114.7958384
# 174 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.270542
# 210 simplex iterations
# 1 branching nodes
# absmipgap=0.00523913, relmipgap=3.99109e-05
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.1864250563724998e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 115.8103626
# 245 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 75.89053289
# 185 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 94.4901002
# 150 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 116.4825487
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 111.8406327
# 249 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 129.8633023
# 197 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 91.63049391
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 100.7288992
# 203 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 53.19470394
# 173 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.2315509
# 149 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 122.6301605
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 186.2617574
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 220.990195
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 203.9733605
# 182 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 231.7472816
# 219 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 238.9589103
# 211 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 180.0912214
# 129 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 136.6554254
# 182 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 148.8941795
# 214 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 141.9815131
# 239 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.9046496
# 211 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 77.47442768
# 242 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 217.889321
# 214 simplex iterations
# 1 branching nodes
# absmipgap=0.0119244, relmipgap=5.47268e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 106.1688349
# 150 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 81.93059709
# 199 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 174.0988585
# 205 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 111.191062
# 214 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 151.9030163
# 143 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 129.1611992
# 197 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 162.3248644
# 161 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 86.44225327
# 184 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 127.4475284
# 220 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 106.727336
# 170 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 108.1569553
# 215 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 106.1501662
# 198 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 101.1604014
# 206 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 91.10692931
# 198 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 60.29143409
# 214 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 197.8009199
# 159 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.4632787
# 210 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 62.66643088
# 195 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 76.47145427
# 186 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 82.25987057
# 193 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 170.0515191
# 154 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 188.8315957
# 176 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 165.3926847
# 173 simplex iterations
# 1 branching nodes
# absmipgap=0.00991738, relmipgap=5.99626e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 160.4290753
# 200 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 171.9865903
# 249 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 197.9089775
# 229 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 234.5657714
# 224 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 231.1687745
# 202 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 210.0514907
# 165 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 302.5381813
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 306.6225404
# 186 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 329.7041873
# 229 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 251.5626269
# 217 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 192.2580381
# 177 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 169.9085828
# 240 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 231.5018624
# 134 simplex iterations
# 1 branching nodes
# absmipgap=1.09241e-07, relmipgap=4.71879e-10
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 227.5701284
# 180 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 293.9144801
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 185.8101978
# 227 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 244.0525358
# 198 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 204.4454559
# 230 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 259.7624715
# 178 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 256.3898213
# 166 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 300.585677
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 220.7796481
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 289.8803837
# 179 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 157.5325512
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 370.5563492
# 244 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 98.93861843
# 179 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 355.6767816
# 184 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 239.954368
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 296.608258
# 185 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 328.635685
# 213 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 234.0825383
# 208 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 309.9688129
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 323.8643754
# 148 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 345.6412987
# 142 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 447.6597021
# 200 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 324.2360609
# 222 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 404.469481
# 189 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 304.0810699
# 210 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 272.0329574
# 199 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 193.1211427
# 178 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 342.7738737
# 133 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 267.1375836
# 231 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 358.6173648
# 225 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.1960576517507176e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 286.0882774
# 209 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 265.5450626
# 202 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 221.3995271
# 215 simplex iterations
# 1 branching nodes
# absmipgap=8.52651e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 208.8870679
# 180 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 231.7276006
# 221 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 364.2007713
# 223 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 417.3911151
# 226 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 550.9028775
# 272 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 451.7178644
# 222 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 316.3234886
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 422.8202232
# 213 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 447.5794021
# 248 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 440.7496327
# 245 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 397.9755158
# 261 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 447.1977751
# 251 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 488.6423258
# 250 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 571.5604121
# 226 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.198430344462654e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 507.1920467
# 234 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 442.455226
# 259 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 491.4365275
# 242 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 514.6241167
# 222 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 381.0211618
# 233 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 378.1021531
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 325.8207628
# 230 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 357.6496392
# 249 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 607.8676217
# 279 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 565.8402246
# 255 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 612.1571264
# 234 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 611.4881987
# 263 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 521.6407436
# 269 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 498.0325354
# 219 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 359.4806072
# 249 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 732.9021196
# 254 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 775.5454209
# 272 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 462.4621705
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 536.3505625
# 283 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 501.3152028
# 292 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 456.1609473
# 233 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 616.1224284
# 204 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 727.7188207
# 250 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 889.4453851
# 298 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 894.1027967
# 260 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 465.8385669
# 243 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 362.2656534
# 235 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 473.5482469
# 237 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 343.5637968
# 267 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 343.7366181
# 273 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 547.9568041
# 254 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 375.980124
# 233 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 241.1235518
# 237 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 400.8891117
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 599.2763188
# 266 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 307.8154181
# 326 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 373.2483136
# 277 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 996.197569
# 261 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 393.0941454
# 281 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 432.4149428
# 250 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 533.8613174
# 248 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 432.7396788
# 235 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 272.2144981
# 208 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 315.9770115
# 235 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 655.0741953
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 509.8406423
# 293 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 414.4873957
# 242 simplex iterations
# 1 branching nodes
# absmipgap=8.03421e-07, relmipgap=1.93835e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 589.39939
# 250 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 451.4913738
# 289 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 244.2330378
# 253 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 482.0938341
# 277 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 496.8660422
# 275 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 632.502104
# 238 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 423.5930234
# 278 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 512.828325
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 415.009444
# 259 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 288.282599
# 204 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 349.7696513
# 298 simplex iterations
# 1 branching nodes
# absmipgap=0.0156342, relmipgap=4.46985e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 423.2890535
# 275 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 436.274775
# 273 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 414.9401211
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 189.4285012
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 348.9729348
# 245 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.2085116581439433e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 152.4444384
# 238 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 277.6955925
# 249 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 501.298379
# 252 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 257.2693931
# 244 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 199.9819275
# 266 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 194.7393702
# 222 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 121.8356477
# 231 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 140.23491
# 256 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.4297459
# 231 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 255.9832229
# 212 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 189.0465425
# 286 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 123.8494893
# 248 simplex iterations
# 1 branching nodes
# absmipgap=0.00451967, relmipgap=3.64932e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 161.6340138
# 262 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.8322309
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 95.69374759
# 246 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 51.34962573
# 223 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 146.6977302
# 234 simplex iterations
# 1 branching nodes
# absmipgap=0.00818443, relmipgap=5.57911e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 201.6946819
# 293 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 169.0403539
# 233 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.6217178
# 240 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 133.3394341
# 247 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 98.13525927
# 224 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 156.897558
# 286 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 211.1288126
# 277 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.2123664747187187e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 114.3877616
# 239 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 202.4274672
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 203.30429
# 289 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 186.6195167
# 241 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 127.4292028
# 252 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 82.01482266
# 216 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 213.6885847
# 239 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 151.993524
# 268 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 165.8858968
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 174.6692469
# 223 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 174.3255712
# 312 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 194.9771015
# 248 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.5636221
# 249 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 395.785624
# 289 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 190.9466411
# 244 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 166.212321
# 240 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 212.4727214
# 210 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 215.4974659
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 126.36758
# 253 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 107.2960551
# 316 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 360.7308357
# 278 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 261.6741229
# 238 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 213.3260488
# 217 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 232.2951839
# 225 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 187.5214355
# 201 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 153.5444473
# 240 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 168.1183228
# 395 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 369.8680426
# 280 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 249.3426217
# 235 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 265.2217695
# 283 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 229.9490628
# 259 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 182.5066429
# 248 simplex iterations
# 1 branching nodes
# absmipgap=8.52651e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 143.2827281
# 235 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.6945297
# 195 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 277.4328108
# 258 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.2173398775634462e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 353.5383029
# 224 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 297.1002432
# 217 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 282.9037957
# 200 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 358.6803355
# 254 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 95.58763569
# 167 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 159.8222813
# 262 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 431.0189575
# 256 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 176.768109
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 92.41435677
# 187 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 123.0928058
# 264 simplex iterations
# 1 branching nodes
# absmipgap=4.26326e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 101.7183958
# 162 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 154.5691511
# 237 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 68.57280759
# 246 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 156.4880342
# 282 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 173.7658471
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 137.3724795
# 222 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 158.7541505
# 269 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 63.045819
# 230 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.219788906470817e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 84.49912196
# 201 simplex iterations
# 1 branching nodes

# %% [markdown]
# # Get Schedule with forecasted prices :

# %%
for frame_size_forecast in []:
    update_period = 1

    df_pred = run_simulation(
        bat,
        start="2022-01-01 00:00:00",
        end="2023-01-01 00:00:00",
        df=df,
        forecasted=True,
        frame_size=frame_size_forecast,
        update_period=update_period,
    )

    display_schedule(df_pred, name=country + "_pred_" + str(frame_size_forecast))
    display_profit(df_pred, name=country + "_pred_" + str(frame_size_forecast))
    get_stats(df_pred, df_optim, name=country + "_" + str(frame_size_forecast))
# Out:
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 135.5313858
# 227 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 135.3782732
# 226 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 129.6992807
# 197 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 127.650348
# 196 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 120.6486452
# 250 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 116.1117193
# 251 simplex iterations
# 1 branching nodes
# absmipgap=0.000110053, relmipgap=9.47819e-07
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 114.4478181
# 222 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 112.7433399
# 237 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 111.6047785
# 238 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 112.0328223
# 246 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.5277736
# 231 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 93.59359661
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 88.70904303
# 224 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 88.65438258
# 184 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 89.24150424
# 247 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 89.38380506
# 227 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 83.11793606
# 204 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 88.47155947
# 235 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 88.37577206
# 216 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 88.33853349
# 233 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 91.82500629
# 223 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 94.62354132
# 238 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 96.42069556
# 219 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 97.3397085
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 98.23396892
# 214 simplex iterations
# 1 branching nodes
# absmipgap=4.26326e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 106.6087512
# 223 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 108.1547737
# 215 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 101.7913785
# 220 simplex iterations
# 1 branching nodes
# absmipgap=5.52465e-07, relmipgap=5.42742e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 101.2711356
# 228 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 101.0026758
# 221 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.6125316
# 215 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 104.2755234
# 206 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 99.34143964
# 224 simplex iterations
# 1 branching nodes
# absmipgap=4.26326e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.7262339
# 199 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 100.8519959
# 193 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 95.8874212
# 193 simplex iterations
# 1 branching nodes
# absmipgap=5.52013e-07, relmipgap=5.75689e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 98.17595425
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.8895879
# 233 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 103.4681477
# 226 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.61914
# 190 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 105.4966667
# 211 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 103.2427678
# 234 simplex iterations
# 1 branching nodes
# absmipgap=4.26326e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 104.5691562
# 219 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.8859265
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.6987896
# 221 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.0214099
# 199 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 96.50788649
# 192 simplex iterations
# 1 branching nodes
# absmipgap=4.26326e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 95.38552418
# 190 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 101.8299806
# 193 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 101.8091335
# 243 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 105.1601663
# 181 simplex iterations
# 1 branching nodes
# absmipgap=4.26326e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 98.46406542
# 204 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 96.28194867
# 203 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 99.96976697
# 199 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 97.54108179
# 197 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 98.02928356
# 214 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 98.53817038
# 194 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 101.5699804
# 211 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 107.3418538
# 223 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 108.6564002
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 115.1266294
# 203 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 117.7072669
# 226 simplex iterations
# 1 branching nodes
# absmipgap=4.26326e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 122.5997936
# 182 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 124.1353069
# 231 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.9861158
# 179 simplex iterations
# 1 branching nodes
# absmipgap=2.97921e-07, relmipgap=2.30971e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 134.7368269
# 210 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 141.8948963
# 222 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 164.260527
# 214 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 178.1087388
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 184.4893928
# 209 simplex iterations
# 1 branching nodes
# absmipgap=0.0173514, relmipgap=9.4051e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 188.1475698
# 202 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 192.8046385
# 243 simplex iterations
# 1 branching nodes
# absmipgap=4.70506e-07, relmipgap=2.44033e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 200.9306303
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 209.2721063
# 175 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 211.9577582
# 200 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 210.5658362
# 236 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 216.7326898
# 191 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 218.040489
# 197 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 216.9100305
# 234 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 212.8680118
# 194 simplex iterations
# 1 branching nodes
# absmipgap=0.0115314, relmipgap=5.41716e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 214.1263033
# 217 simplex iterations
# 1 branching nodes
# absmipgap=0.0194668, relmipgap=9.09127e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 212.1892453
# 220 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 212.4695453
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 212.9274281
# 222 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 214.0166818
# 227 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 214.1800928
# 370 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 214.1273532
# 232 simplex iterations
# 1 branching nodes
# absmipgap=0.000146213, relmipgap=6.82832e-07
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 210.9249704
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 191.2863955
# 202 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 178.6547378
# 178 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 171.1066681
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 167.1150399
# 219 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 164.7694161
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 160.9279163
# 191 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 150.394156
# 187 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 153.0981338
# 185 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 152.5823794
# 179 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 144.5013684
# 227 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 150.1982268
# 198 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 147.6616814
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 154.3384494
# 194 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 149.8319773
# 198 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 149.7241971
# 172 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 147.8142033
# 237 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 144.1425435
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 137.8320377
# 199 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 137.3249512
# 378 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.1853203024723562e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.2249263
# 382 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 136.2104079
# 203 simplex iterations
# 1 branching nodes
# absmipgap=3.30035e-07, relmipgap=2.42298e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 135.6086729
# 326 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.1856759696941712e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 136.9542939
# 219 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.185794549149086e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 136.0694859
# 167 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 136.8393383
# 200 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.186031743637496e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.1380185
# 198 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 142.0627694
# 189 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 145.7610905
# 394 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 140.7165752
# 168 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 140.1186984
# 187 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 144.9513212
# 241 simplex iterations
# 1 branching nodes
#
# "option abs_boundtol 5.820766091346741e-11;"
# or "option rel_boundtol 1.1867436118167774e-16;"
# will change deduced dual values.
#
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 139.0078159
# 217 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.9443444
# 175 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.6883924
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.4541587
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 125.7309931
# 194 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 123.8228933
# 223 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 122.267611
# 204 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 123.7299631
# 193 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 118.997899
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 116.3938135
# 213 simplex iterations
# 1 branching nodes
# absmipgap=0.000667723, relmipgap=5.73676e-06
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 113.3868693
# 218 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 115.9174674
# 370 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 120.729565
# 220 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 125.3095128
# 215 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.9221708
# 200 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.7924624
# 184 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.4003453
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.7650268
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 133.0626483
# 197 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 134.3108134
# 213 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 134.2259366
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 132.423042
# 415 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.4833897
# 203 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.7041834
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 136.9734255
# 177 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 139.4027017
# 213 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 137.7204737
# 231 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 139.1850987
# 206 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 139.1256833
# 187 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 143.4361089
# 184 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 140.3937277
# 182 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 140.4910322
# 200 simplex iterations
# 1 branching nodes
# absmipgap=2.61948e-07, relmipgap=1.86451e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 136.7868725
# 197 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.1385055
# 216 simplex iterations
# 1 branching nodes
# absmipgap=0.00462096, relmipgap=3.52373e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 126.753992
# 209 simplex iterations
# 1 branching nodes
# absmipgap=0.00340585, relmipgap=2.68698e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 120.7143382
# 185 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 113.9136326
# 202 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 108.5774263
# 175 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 110.8836612
# 220 simplex iterations
# 1 branching nodes
# absmipgap=0.00473715, relmipgap=4.27218e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 109.0123888
# 185 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 105.7368919
# 171 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 103.1566181
# 168 simplex iterations
# 1 branching nodes
# absmipgap=2.93402e-07, relmipgap=2.84424e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 103.6429296
# 203 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 100.2118935
# 206 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.6946981
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 107.3901102
# 194 simplex iterations
# 1 branching nodes
# absmipgap=2.30622e-07, relmipgap=2.14752e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 106.4284277
# 194 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 108.724967
# 215 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 110.7001899
# 174 simplex iterations
# 1 branching nodes
# absmipgap=2.85382e-08, relmipgap=2.57797e-10
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 116.9479147
# 178 simplex iterations
# 1 branching nodes
# absmipgap=1.38232e-07, relmipgap=1.182e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 121.1847777
# 196 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 124.9884337
# 193 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 132.7777051
# 193 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 141.5513297
# 220 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 151.8397472
# 190 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 158.2824261
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 162.3011723
# 155 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 165.8700763
# 203 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 171.8493992
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 173.9458149
# 214 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 182.6446763
# 198 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 188.1678638
# 237 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 196.8395914
# 211 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 199.5606171
# 208 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 204.1297062
# 176 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 208.7613633
# 185 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 215.2436142
# 184 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 217.7363095
# 203 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 222.2709783
# 311 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 219.88409
# 206 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 225.5139907
# 325 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 217.9145583
# 414 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 225.1848921
# 191 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 222.8931793
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 222.1559859
# 220 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 221.5913047
# 172 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 221.6556706
# 238 simplex iterations
# 1 branching nodes
# absmipgap=8.52651e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 226.7982429
# 203 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 229.3463295
# 200 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 236.89867
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 247.9557742
# 205 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 249.3802338
# 206 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 258.6477166
# 189 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 263.3628392
# 192 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 268.0419439
# 214 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 264.967572
# 210 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 265.6233206
# 208 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 264.1831499
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 269.6643689
# 204 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 269.4605635
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 273.9091217
# 179 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 265.5638952
# 190 simplex iterations
# 1 branching nodes
# absmipgap=1.13687e-13, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 271.5278082
# 224 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 265.9080436
# 185 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 265.6101688
# 187 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 269.6624262
# 187 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 278.6071746
# 212 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 285.3660942
# 188 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 282.1793705
# 166 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 288.7519897
# 180 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 289.7683004
# 194 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 286.4303151
# 199 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 290.9933505
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 291.0201516
# 227 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 296.1057721
# 203 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 302.7647768
# 205 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 312.4828473
# 197 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 318.8994734
# 206 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 322.9613839
# 209 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 330.4316149
# 211 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 332.3645522
# 225 simplex iterations
# 1 branching nodes
# absmipgap=6.97657e-07, relmipgap=2.09907e-09
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 336.5998841
# 186 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 340.0955639
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 346.4736593
# 230 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 358.1259626
# 195 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 363.1641932
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 373.359589
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 370.8568737
# 230 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 374.0989748
# 223 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 384.6780684
# 211 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 379.3517789
# 208 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 395.661489
# 235 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 410.0008177
# 185 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 408.8439431
# 221 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 408.5150044
# 204 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 406.243291
# 189 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 406.4870681
# 206 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 412.8489979
# 215 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 428.0006894
# 214 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 434.7316855
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 447.9786243
# 190 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 450.7469746
# 219 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 450.4225642
# 205 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 457.823982
# 192 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 457.3809421
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 450.9249628
# 213 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 455.4638646
# 204 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 443.0491341
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 430.3226265
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 426.6331462
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 428.2973465
# 206 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 420.8856524
# 244 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 397.6213774
# 179 simplex iterations
# 1 branching nodes
# absmipgap=0.0299647, relmipgap=7.53599e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 412.164892
# 224 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 410.67707
# 212 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 408.1322984
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 411.4080895
# 183 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 411.8722235
# 175 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 397.2700431
# 195 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 379.232377
# 217 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 384.0664326
# 220 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 367.5011264
# 177 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 367.1083558
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 380.5997364
# 186 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 377.2010927
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 369.5029956
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 372.3606049
# 194 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 364.5454996
# 233 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 375.8456558
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 381.7704254
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 386.2114318
# 227 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 377.4799511
# 209 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 383.8735103
# 223 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 388.8104378
# 213 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 360.8518877
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 363.7576432
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 365.1182156
# 227 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 349.4330936
# 235 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 344.4758486
# 211 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 336.7710219
# 211 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 334.3688522
# 229 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 322.9885681
# 241 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 313.489148
# 222 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 302.4208278
# 237 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 284.4885356
# 277 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 275.4327948
# 219 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 273.1581776
# 230 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 260.712797
# 221 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 257.7732329
# 237 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 237.3764831
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 229.519563
# 244 simplex iterations
# 1 branching nodes
# absmipgap=0.0183042, relmipgap=7.97501e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 212.6221638
# 223 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 201.481127
# 239 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 191.2598019
# 224 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 177.1975878
# 213 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 168.9258939
# 200 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 156.8385798
# 209 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 143.8139735
# 201 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.6230474
# 203 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.9340049
# 239 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 130.2431781
# 229 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 122.1834604
# 221 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 109.8757238
# 207 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 103.6226504
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 102.9229549
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 105.839665
# 203 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 109.0567573
# 189 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 109.548438
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 107.133025
# 237 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 106.1122545
# 205 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 107.2581609
# 230 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 109.4861666
# 200 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 111.1321465
# 370 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 111.8380485
# 210 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 116.1556161
# 235 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 117.7767312
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 124.9814615
# 220 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.6102691
# 213 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.6117905
# 255 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 131.9618252
# 261 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 137.1191173
# 214 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 139.3339451
# 225 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 136.3572306
# 246 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 140.1776525
# 246 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 147.5052927
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 147.680921
# 247 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 147.5303501
# 247 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 141.5207476
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 139.0549227
# 204 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 138.5289412
# 173 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 141.1626883
# 191 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 143.7409369
# 235 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 146.5460041
# 253 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 148.3878962
# 244 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 150.7248317
# 237 simplex iterations
# 1 branching nodes
# absmipgap=5.68434e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 148.8189912
# 217 simplex iterations
# 1 branching nodes
# absmipgap=0.0136495, relmipgap=9.17185e-05
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 149.8363171
# 167 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 151.9122342
# 169 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 158.797429
# 239 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 166.6247873
# 207 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 167.0022718
# 191 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 166.9925318
# 229 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 164.700449
# 192 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 163.9850324
# 171 simplex iterations
# 1 branching nodes
# absmipgap=2.84217e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 162.2046747
# 218 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 156.8207807
# 210 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 151.2450672
# 211 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 145.7708965
# 228 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 145.0982695
# 221 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 144.6887138
# 232 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 143.5377975
# 216 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 130.8860153
# 214 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 128.5807564
# 206 simplex iterations
# 1 branching nodes
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective 125.20471
# 193 simplex iterations
# 1 branching nodes
# absmipgap=1.42109e-14, relmipgap=0
# Gurobi 10.0.0:Gurobi 10.0.0: optimal solution; objective